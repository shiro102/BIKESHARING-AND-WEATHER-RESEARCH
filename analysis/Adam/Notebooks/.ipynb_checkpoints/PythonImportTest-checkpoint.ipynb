# %% [markdown]
# # Markdown Test
# ## By: Adam Collins
# #### I hope this is what you expected for the Markdown task.
# > I hope this __counts__.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

from scripts import project_functions

df = project_functions.load_and_process("../../../data/raw/day.csv")
df
project_functions.Graph1(df)
print("\nWith this simple function call four graphs are made!\nThere is one for each season and within them you can see how many Users are active based on the weather during that season!\nAlso each point has a color that can show what day of the week is most popular!\nSomething I found interesting is that the time with the most users in the nicest weather was fall instead of summer.\nWhich makes me think that maybe the heat is something deterring users mmore than I would have assumed.")
# Out:
# DataFrame Shape (731, 18)
# Year                   0.500684
# Month                  6.519836
# Holiday                0.028728
# Working_day            0.683995
# Temperature            0.495385
# FeelTemp               0.474354
# Humidity               0.627894
# Wind_speed             0.190486
# Casual_users         848.176471
# Registered_users    3656.172367
# Total_users         4504.348837
# Average_Temp           0.484869
# Casual_ratio           0.175598
# Registered_ratio       0.824402
# dtype: float64
#
# With this simple function call four graphs are made!
# There is one for each season and within them you can see how many Users are active based on the weather during that season!
# Also each point has a color that can show what day of the week is most popular!
# Something I found interesting is that the time with the most users in the nicest weather was fall instead of summer.
# ...
