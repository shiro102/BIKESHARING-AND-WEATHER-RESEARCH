# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling

# %%
def load_and_process(url_or_path_to_csv_file):

    # Method Chain 1 (Load data and deal with missing data)

    df1 = (
        pd.read_csv(url_or_path_to_csv_file)
        .rename(columns = {"instant":"Index", "dteday":"Date","season":"Season","yr":"Year","mnth":"Month","hr":"Hour","holiday":"Holiday","weekday":"Week_day","workingday":"Working_day",
                            "weathersit":"Weather","temp":"Temperature","atemp":"FeelTemp","hum":"Humidity","windspeed":"Wind_speed","casual":"Casual_users","registered":"Registered_users",
                            "cnt": "Total_users"}, errors = "ignore")
        .dropna(axis = 0, how = "any")
        .drop(columns = "Index", errors = "ignore")
      )

    # Method Chain 2 (Create new columns, drop others, and do processing)

    df2 = (
        df1
        .assign(Casual_ratio = lambda x : x['Casual_users'] / x['Total_users'])
        .assign(Registered_ratio = lambda x : x['Registered_users'] / x['Total_users'])
      )
    # Replace weather conditions in column weather
    df2['Weather'] = df2['Weather'].replace([1,2,3,4],["Good(clear or cloudy)","Normal(mist or/and cloudy)","Lightly bad(light snow, rain, thunderstorm)","Severe(heavy Rain, ice pallets,fog)"])
    # Replace season in column season
    df2['Season'] = df2['Season'].replace([1,2,3,4],["Spring","Summer","Fall","Winter"])
    # Replace weekday in column week_day
    df2['Week_day'] = df2['Week_day'].replace([0,1,2,3,4,5,6],["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"])


    #Convert "Date" column to datetime
    df2['Date'] = pd.to_datetime(df2['Date'])
    
    # Make sure to return the latest dataframe

    return df2

def box_plot_one(df,var1,var2):
    #Make box plot that only has one figure
    sns.set(rc={'figure.figsize':(15,10)})
    ax = sns.boxplot(x = var1, y = var2, data = df, width = 0.9)
    ax.set(ylabel = " ")
    ax.set_title("Box plot of " + var1 + " by " + var2)

def box_plot_two(df,var1,var2,var3,var4):
    #Make box plot that contains two figures
    fig, axs = plt.subplots(ncols=2)
    sns.set(rc={'figure.figsize':(20,10)})
    ax = sns.boxplot(x = var1, y = var2, data = df, width = 0.9, ax = axs[0])
    ax.set(ylabel = " ")
    ax.set_title("Box plot of " + var1 + " by " + var2)
    ax1 = sns.boxplot(x = var3, y = var4, data = df, width = 0.9, ax = axs[1])
    ax1.set(ylabel = " ")
    ax1.set_title("Box plot of " + var3 + " by " + var4)
    plt.tight_layout()

# %%
df=load_and_process("../../../data/raw/day.csv")
#Group by weather between casual and registered users
box_plot_two(df,'Casual_users','Weather', "Registered_users","Weather")

# %%
#group by season
group = df.groupby(['Season']).sum().filter(items = ["Total_users"]).reindex(["Spring","Summer","Fall","Winter"]).plot(kind = "bar",title = "Number of users by season")
group.set_ylabel("Total_users")
# Out:
# Text(0, 0.5, 'Total_users')

# %%
#group by weekdays
group = df.groupby(['Week_day']).sum().filter(items = ["Total_users"]).reindex(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]).plot(kind = "bar",title = "Number of users by week days")
group.set_ylabel("Total_users")
# Out:
# Text(0, 0.5, 'Total_users')

# %%
df1=load_and_process("../../../data/raw/hour.csv")
df1
# Out:
#             Date  Season  Year  Month  Hour  Holiday  Week_day  Working_day  \
# 0     2011-01-01  Spring     0      1     0        0  Saturday            0
# 1     2011-01-01  Spring     0      1     1        0  Saturday            0
# 2     2011-01-01  Spring     0      1     2        0  Saturday            0
# 3     2011-01-01  Spring     0      1     3        0  Saturday            0
# 4     2011-01-01  Spring     0      1     4        0  Saturday            0
# ...          ...     ...   ...    ...   ...      ...       ...          ...
# 17374 2012-12-31  Spring     1     12    19        0    Monday            1
# 17375 2012-12-31  Spring     1     12    20        0    Monday            1
# 17376 2012-12-31  Spring     1     12    21        0    Monday            1
# 17377 2012-12-31  Spring     1     12    22        0    Monday            1
# 17378 2012-12-31  Spring     1     12    23        0    Monday            1
#
#                           Weather  Temperature  FeelTemp  Humidity  \
# 0           Good(clear or cloudy)         0.24    0.2879      0.81
# 1           Good(clear or cloudy)         0.22    0.2727      0.80
# 2           Good(clear or cloudy)         0.22    0.2727      0.80
# 3           Good(clear or cloudy)         0.24    0.2879      0.75
# 4           Good(clear or cloudy)         0.24    0.2879      0.75
# ...                           ...          ...       ...       ...
# 17374  Normal(mist or/and cloudy)         0.26    0.2576      0.60
# 17375  Normal(mist or/and cloudy)         0.26    0.2576      0.60
# 17376       Good(clear or cloudy)         0.26    0.2576      0.60
# 17377       Good(clear or cloudy)         0.26    0.2727      0.56
# 17378       Good(clear or cloudy)         0.26    0.2727      0.65
#
#        Wind_speed  Casual_users  Registered_users  Total_users  Casual_ratio  \
# 0          0.0000             3                13           16      0.187500
# 1          0.0000             8                32           40      0.200000
# 2          0.0000             5                27           32      0.156250
# 3          0.0000             3                10           13      0.230769
# 4          0.0000             0                 1            1      0.000000
# ...           ...           ...               ...          ...           ...
# 17374      0.1642            11               108          119      0.092437
# 17375      0.1642             8                81           89      0.089888
# 17376      0.1642             7                83           90      0.077778
# 17377      0.1343            13                48           61      0.213115
# 17378      0.1343            12                37           49      0.244898
#
#        Registered_ratio
# 0              0.812500
# 1              0.800000
# 2              0.843750
# 3              0.769231
# 4              1.000000
# ...                 ...
# 17374          0.907563
# 17375          0.910112
# 17376          0.922222
# 17377          0.786885
# 17378          0.755102
#
# [17379 rows x 18 columns]

# %%
ax = sns.pairplot(df1, x_vars = ['Hour'], y_vars = ['Hour','Total_users','Casual_users',"Registered_users"],kind = "scatter", aspect = 2)

# %%
#Plot windspeed and total_guest to find any correlations 
group = df.groupby("Wind_speed").sum().filter(items = ["Wind_speed","Total_users"]).sort_values("Wind_speed",ascending = True)
group.plot(title = "Number of users by wind speed")
# Out:
# <AxesSubplot:title={'center':'Number of users by wind speed'}, xlabel='Wind_speed'>

# %%
#Plot windspeed and total_guest to find any correlations 
group = df.groupby("Humidity").sum().filter(items = ["Humidity","Total_users"]).sort_values("Humidity",ascending = True)
group.plot(title = "Number of users by humidity")
# Out:
# <AxesSubplot:title={'center':'Number of users by humidity'}, xlabel='Humidity'>

# %%
group = df.groupby("Season").mean().filter(items = ["Humidity"]).sort_values("Humidity",ascending = True)
group
# Out:
#         Humidity
# Season
# Spring  0.582903
# Summer  0.626948
# Fall    0.633482
# Winter  0.668719

# %%
holiday = df.groupby("Holiday").sum().filter(items = ["Total_users"])
holiday.plot(kind = "bar",title = "Number of users betweem normal day and holiday")
# Out:
# <AxesSubplot:title={'center':'Number of users betweem normal day and holiday'}, xlabel='Holiday'>
